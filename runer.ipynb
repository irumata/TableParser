# %%
from parser import TestTableParser
import pandas as pd

testTableParser = TestTableParser()
xlsx = pd.ExcelFile('file1.xlsx')
names = xlsx.sheet_names
sheet_to_df_map = {}
for i in range(len(names)):
	sheet_to_df_map[names[i]] = testTableParser.all_action(
		pd.read_excel(open('file1.xlsx', 'rb'), header=None, sheet_name=names[i]))

print(xlsx.sheet_names)
sheet_to_df_map.get('TDSheet')[0]
# Out:
# False
# ['TDSheet']
#      nan                      ПАО "Птицефабрика "Боровская"  \
# 3    NaN  Показатели продуктивного периода   1 Марта 201...
# 4    NaN                                                NaN
# 5    NaN                                                NaN
# 6    NaN                                                NaN
# 7    NaN                                                NaN
# ..   ...                                                ...
# 922  NaN                                                NaN
# 923  NaN                                                NaN
# 924  NaN                                                NaN
# 925  NaN                                                NaN
# 926  NaN                                                NaN
#
#     Цех №2__Птичник: Пт № 16 Цех №2__Птичник: Пт № 16 Показатели__ЕдИзм  \
# 3                        NaN                      NaN               NaN
# 4                        NaN                      NaN               NaN
# ...

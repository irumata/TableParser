# %%
from parser import TestTableParser
import pandas as pd

testTableParser = TestTableParser()
xlsx = pd.ExcelFile('file44.xlsx')
names = xlsx.sheet_names
sheet_to_df_map = {}
for i in range(len(names)):
	sheet_to_df_map[names[i]] = testTableParser.all_action(
		pd.read_excel(open('file44.xlsx', 'rb'), header=None, sheet_name=names[i]))
print(xlsx.sheet_names)
# Out:
# ['Лист1']

# %%
sheet_to_df_map.get('Лист1')[0]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1           10107               30       95.7                2   2871.0
# 2           10121               34      81.35                5   2765.9
# 3           10134               41      94.74                2  3884.34
# 4           10145               45      83.26                6   3746.7
# 5           10159               49      100.0               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2819        10350               20      100.0               15   2244.4
# 2820        10373               29      100.0                1  3978.51
# 2821        10386               43      100.0                4  5417.57
# 2822        10397               34      62.24                1  2116.16
# 2823        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 1      2/24/2003 0:00   Shipped       1         2     2003  ...
# 2       5/7/2003 0:00   Shipped       2         5     2003  ...
# 3       7/1/2003 0:00   Shipped       3         7     2003  ...
# 4      8/25/2003 0:00   Shipped       3         8     2003  ...
# 5     10/10/2003 0:00   Shipped       4        10     2003  ...
# ...               ...       ...     ...       ...      ...  ...
# 2819   12/2/2004 0:00   Shipped       4        12     2004  ...
# 2820   1/31/2005 0:00   Shipped       1         1     2005  ...
# 2821    3/1/2005 0:00  Resolved       1         3     2005  ...
# 2822   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2823    5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                        ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 1           897 Long Airport Avenue           NaN            NYC    NY
# 2                59 rue de l'Abbaye           NaN          Reims   NaN
# 3     27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 4                78934 Hillside Dr.           NaN       Pasadena    CA
# 5                   7734 Strong St.           NaN  San Francisco    CA
# ...                             ...           ...            ...   ...
# 2819             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2820                    Torikatu 38           NaN           Oulu   NaN
# 2821             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2822          1 rue Alsace-Lorraine           NaN       Toulouse   NaN
# 2823             8616 Spinnaker Dr.           NaN         Boston    MA
#
#       POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  DEALSIZE
# 1          10022      USA       NaN              Yu             Kwai     Small
# 2          51100   France      EMEA         Henriot             Paul     Small
# 3          75508   France      EMEA        Da Cunha           Daniel    Medium
# 4          90003      USA       NaN           Young            Julie    Medium
# 5           <NA>      USA       NaN           Brown            Julie    Medium
# ...          ...      ...       ...             ...              ...       ...
# 2819       28034    Spain      EMEA          Freyre            Diego     Small
# 2820       90110  Finland      EMEA       Koskitalo           Pirkko    Medium
# 2821       28034    Spain      EMEA          Freyre            Diego    Medium
# 2822       31000   France      EMEA          Roulet          Annette     Small
# 2823       51003      USA       NaN         Yoshido             Juri    Medium
#
# [2823 rows x 25 columns]
